# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import ephem

# %%
veritas = ephem.Observer()
veritas.lon, veritas.lat = '-110.952158','31.675058'
veritas.elevation = 1200.

# %%
grb = ephem.FixedBody(173.1370800,27.6990200)

# %%
dates = []
alts = []
moon = []
veritas.date = '2013/4/27 08:05:12'
for t in range(5000):  
    grb.compute(veritas)
    m = ephem.Moon(veritas)
    #print veritas.date,grb.alt
    dates = np.append(dates,veritas.date)
    alts = np.append(alts, np.degrees(grb.alt))
    moon = np.append(moon, np.degrees(m.alt))
    veritas.date += 1./(24.*60.)

# %%
plot(dates, alts + 90)
plot(dates, moon + 90)
