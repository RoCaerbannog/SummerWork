# %% [markdown]
# # The Extraordinary GRB 130427A

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
rcParams['font.size'] = 20.

# %%
from VOT import *

# %%
from VOTPlot import Plot, PlotSpectrum

# %%
from GPlot import plotG, plotG_all

# %%
baseline_1 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.000244, index = -2.61, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 2.44e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 3.94e-11 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 3.61e-12 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 2.22e+04
# INFO - This is approximately 3,369.4113% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_1)

# %%
baseline_2 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.00109, index = -2.34, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.09e-03 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 8.88e-10 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 1.04e-10 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 4.44e+05
# INFO - This is approximately 67,438.7303% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_2)

# %%
baseline_3 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.00303, index = -2.26, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 3.03e-03 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 3.99e-09 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 5.03e-10 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 1.93e+06
# INFO - This is approximately 292,791.6483% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_3)

# %%
baseline_4 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.00126, index = -1.78, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.26e-03 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 2.94e-08 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 5.76e-09 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 1.18e+07
# INFO - This is approximately 1,796,704.6087% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_4)

# %%
baseline_5 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.00157, index = -1.75, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.57e-03 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 4.39e-08 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 8.83e-09 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 1.75e+07
# INFO - This is approximately 2,651,689.4541% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_5)

# %%
baseline_6 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.00102, index = -2.18, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.02e-03 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 2.17e-09 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 2.94e-10 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 1.02e+06
# INFO - This is approximately 154,052.2807% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_6)

# %%
baseline_7 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.000798, index = -2.06, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 7.98e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 3.48e-09 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 5.27e-10 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 1.55e+06
# INFO - This is approximately 235,844.4586% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_7)

# %%
baseline_8 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.000373, index = -1.84, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 3.73e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 6.08e-09 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 1.13e-09 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 2.50e+06
# INFO - This is approximately 379,275.2599% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_8)

# %%
baseline_9 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.000244, index = -1.98, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 2.44e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 1.72e-09 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 2.80e-10 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 7.44e+05
# INFO - This is approximately 112,933.1587% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_9)

# %%
baseline_10 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.000256, index = -2.03, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 2.56e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 1.34e-09 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 2.08e-10 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 5.90e+05
# INFO - This is approximately 89,510.4655% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_10)

# %%
baseline_11 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.000247, index = -2.51, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 2.47e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 7.27e-11 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 7.29e-12 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 3.91e+04
# INFO - This is approximately 5,938.9746% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_11)

# %%
baseline_12 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.00017, index = -1.8, E0 = 1 )
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.70e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 3.52e-09 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 6.77e-10 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 1.43e+06
# INFO - This is approximately 216,558.9551% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_12)

# %%
baseline_13 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.000171, index  = -2.04, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.71e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 8.41e-10 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 1.30e-10 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 3.73e+05
# INFO - This is approximately 56,531.0908% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_13)

# %%
baseline_14 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.000188, index  = -2.31, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.88e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 1.83e-10 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 2.21e-11 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 9.06e+04
# INFO - This is approximately 13,747.2754% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_14)

# %%
baseline_15 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=0.000115, index  = -2.35, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.15e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 8.83e-11 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 1.02e-11 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 4.43e+04
# INFO - This is approximately 6,729.7412% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_15)

# %%
baseline_16 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0= 7.12e-05, index  = -2.07, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 7.12e-05 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 2.93e-10 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 4.39e-11 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 1.31e+05
# INFO - This is approximately 19,896.5073% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_16)

# %%
baseline_17 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=8.69e-05, index  = -2.92, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 8.69e-05 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 2.19e-12 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 1.51e-13 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 1.43e+03
# INFO - This is approximately 216.3403% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0155 hours to detect at a 5 sigma level

# %%
plotG(baseline_17)

# %%
baseline_18 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0= 8.68e-05, index  = -2.16, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 8.68e-05 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 2.08e-10 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 2.87e-11 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 9.66e+04
# INFO - This is approximately 14,659.7649% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_18)

# %%
baseline_19 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=9.06e-06, index  = -1.95, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 9.06e-06 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 7.64e-11 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 1.28e-11 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 3.27e+04
# INFO - This is approximately 4,962.5797% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_19)

# %%
baseline_20 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=3.32e-06, index  = -1.85, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 3.32e-06 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 5.10e-11 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 9.36e-12 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 2.10e+04
# INFO - This is approximately 3,191.0166% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_20)

# %%
baseline_21 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=4.27e-06, index  = -2.05, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 4.27e-06 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 1.98e-11 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 3.02e-12 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 8.80e+03
# INFO - This is approximately 1,334.6953% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level

# %%
plotG(baseline_21)

# %%
baseline_22 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=1.19e-06, index  = -2.32, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.19e-06 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 1.09e-12 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 1.30e-13 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 5.42e+02
# INFO - This is approximately 82.3017% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0404 hours to detect at a 5 sigma level

# %%
plotG(baseline_22)

# %%
baseline_23 = VOT("custom", eMin=0.001, eMax=100000, Nbins=100000, redshift= 0.34, eblModel='Dominguez', instrument='VERITAS', zenith=20, 
        spectralModel='PowerLaw', N0=1.24e-07, index  = -1.76, E0 = 1)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 1.24e-07 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 3.26e-12 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 6.51e-13 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 1.30e+03
# INFO - This is approximately 197.9395% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0172 hours to detect at a 5 sigma level

# %%
plotG(baseline_23)

# %%
plotG_all(baseline_1)
plotG_all(baseline_2)
pyplot.show()

# %%
np.arange(1,23)
