# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from LC_VHE_test_v1 import take_data
from LC_VHE_integrate import flux

# %%
GRBs = take_data(Burst = '130427A', redshift = 0.34, eblModel = 'Dominguez', instrument = 'VERITAS', zenith = 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6fa31859a42b> in <module>()
# ----> 1 GRBs = take_data(Burst = '130427A', redshift = 0.34, eblModel = 'Dominguez', instrument = 'VERITAS', zenith = 20)
#
# /Users/ilmorgan/Documents/VHEObserverTools/LC_VHE_test_v1.py in __init__(self, Burst, redshift, eblModel, instrument, zenith)
#      26                 Photon_index = []
#      27                 EF_erg = []
# ---> 28                 EFP_
#      29                 EFM_erg = []
#      30                 Flux_erg = []
#
# NameError: global name 'EFP_' is not defined

# %% [markdown]
# ## First time bin for 130427A

# %%
Time = flux(redshift = 0.34, eblModel = 'Dominguez', instrument = 'VERITAS', zenith = 20, index = -2.61, index_err = 0.704, N0 = 0.000244, start_time = 0.1, stop_time = 7)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_20_Noise_4.07
# INFO - Safe energy range: 177.83 to 25,118.86 GeV
# INFO - dNdE at 1 GeV: 2.44e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 3.94e-11 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 3.61e-12 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 0.39
# INFO - tau at max safe E: 161.84
# INFO - Predicted counts/hour: 2.22e+04
# INFO - This is approximately 3,369.4113% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level
# WARNING - Spectrum starts below minimum energy in EBL table.
# ...

# %%
Time_1 = flux(redshift = 0.34, eblModel = 'Dominguez', instrument = 'VERITAS', zenith = 40, index = -2.61, index_err = 0.704, N0 = 0.000244, start_time = 0.1, stop_time = 7)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_40_Noise_4.07
# INFO - Safe energy range: 316.23 to 39,810.72 GeV
# INFO - dNdE at 1 GeV: 2.44e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 3.94e-11 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 3.61e-12 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 1.16
# INFO - tau at max safe E: 232.44
# INFO - Predicted counts/hour: 4.79e+03
# INFO - This is approximately 727.0460% of the Crab Nebula's Flux
# INFO - This will take approximately 0.0107 hours to detect at a 5 sigma level
# WARNING - Spectrum starts below minimum energy in EBL table.
# ...

# %%
Time_2 = flux(redshift = 0.34, eblModel = 'Dominguez', instrument = 'VERITAS', zenith = 60, index = -2.61, index_err = 0.704, N0 = 0.000244, start_time = 0.1, stop_time = 7)
# Out:
# WARNING - Spectrum starts below minimum energy in EBL table.
# WARNING - Spectrum continues beyond maximum energy in EBL table.
# WARNING - Using 659.0 counts/hr as the rate from the Crab Nebula.
# WARNING - Time to detection assumes a Crab Nebula Spectrum.
# INFO - Using Effective_Areas/VERITAS/ea_Nov2010_na_ATM21_vegasv240rc1_7sam_050off_soft-1.summary.csv
# INFO - Using EffectiveArea_Azimuth_0_Zenith_60_Noise_4.07
# INFO - Safe energy range: 1,584.89 to 70,794.58 GeV
# INFO - dNdE at 1 GeV: 2.44e-04 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 400 GeV: 3.94e-11 s^-1 cm^-2 GeV^-1
# INFO - dNdE at 1 TeV: 3.61e-12 s^-1 cm^-2 GeV^-1
# INFO - tau at min safe E: 5.21
# INFO - tau at max safe E: 232.44
# INFO - Predicted counts/hour: 1.54e+01
# INFO - This is approximately 2.3300% of the Crab Nebula's Flux
# INFO - This will take approximately 5.5183 hours to detect at a 5 sigma level
# WARNING - Spectrum starts below minimum energy in EBL table.
# ...

# %%
Time.make_table(),Time_1.make_table(),Time_2.make_table()
# Out:
# +--------------+-------------------+----------------+-----------+
# | Photon Index |  Integrated Flux  | Percent Error  | detection |
# +--------------+-------------------+----------------+-----------+
# |    -2.61     | 2.40642347302e-05 |      N/A       |  Observed |
# |    -1.906    |  0.00100395230316 | 4071.96854342% |  Observed |
# |    -3.314    |  5.7714199864e-07 | 97.6016607006% |  Observed |
# +--------------+-------------------+----------------+-----------+
# +--------------+-------------------+----------------+--------------+
# | Photon Index |  Integrated Flux  | Percent Error  |  detection   |
# +--------------+-------------------+----------------+--------------+
# |    -2.61     | 2.40642347302e-05 |      N/A       |   Observed   |
# |    -1.906    |  0.00100395230316 | 4071.96854342% |   Observed   |
# |    -3.314    |  5.7714199864e-07 | 97.6016607006% | Not Observed |
# +--------------+-------------------+----------------+--------------+
# ...

# %%
Time.PI_plot(),Time_1.PI_plot(), Time_2.PI_plot()
# Out:
# (None, None, None)

# %%
# Out:
# (None, None, None)
